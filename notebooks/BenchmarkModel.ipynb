# %% [markdown]
# ** Playground. **
#
# * Test different various pipelines on different types of dataset prepared.
#
#
# ** Notes **
#
# * SVR is not working on the transformed ( tsne )  dataset.
# * Random forest regressor works good on the transformed dataset.
# * What if we remove features with low standard deviation ? ( Yes this is a sensible idea )

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import os, sys

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler
from sklearn.feature_selection import f_classif, SelectKBest
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.decomposition import RandomizedPCA
from sklearn.externals import joblib

sns.set_style('whitegrid')
sns.set_context('poster')

import warnings
warnings.filterwarnings('ignore')

basepath = os.path.expanduser('~/Desktop/src/African_Soil_Property_Prediction/')
sys.path.append(os.path.join(basepath, 'src'))

np.random.seed(0)

from models import eval_metric, cross_validation, models_definition
from helper import utils

# %%
# load files
train = pd.read_csv(os.path.join(basepath, 'data/raw/training.csv'))
test = pd.read_csv(os.path.join(basepath, 'data/raw/sorted_test.csv'))
sample_sub = pd.read_csv(os.path.join(basepath, 'data/raw/sample_submission.csv'))

# %%
# labels
labels = utils.get_labels()

# %%
dataset_name = 'dataset_6'

# load training and test sets for every target variable
trains, tests = utils.load_datasets(dataset_name, labels)

# %%
y_Ca, y_P, y_Sand, y_SOC, y_pH = utils.define_target_variables(train)

# %% [markdown]
# ** Cross-validation. **

# %%
def cross_validate(dataset_name, X_trains, y_Ca, y_P, y_Sand, y_SOC, y_pH):
    params = {
        'test_size': 0.2,
        'random_state': 3
        }

    itrain, itest = cross_validation.split_dataset(len(train), **params)
    models        = models_definition.get_models_by_dataset(dataset_name)
    model_names   = os.listdir(os.path.join(basepath, 'data/processed/%s/%s/models'%(dataset_name, 'Ca')))
    
    
    X_train_Ca, X_test_Ca      = utils.get_Xs(X_trains[0], itrain, itest)
    X_train_P, X_test_P        = utils.get_Xs(X_trains[1], itrain, itest)
    X_train_Sand, X_test_Sand  = utils.get_Xs(X_trains[2], itrain, itest)
    X_train_SOC, X_test_SOC    = utils.get_Xs(X_trains[3], itrain, itest)
    X_train_pH, X_test_pH      = utils.get_Xs(X_trains[4], itrain, itest)

    X_trains = [X_train_Ca, X_train_P, X_train_Sand, X_train_SOC, X_train_pH]
    X_tests  = [X_test_Ca, X_test_P, X_test_Sand, X_test_SOC, X_test_pH]

    y_trains, y_tests = utils.get_Ys(y_Ca, y_P, y_Sand, y_SOC, y_pH, itrain, itest)
    
    for i in range(len(models)):
        print('Model: %s\n'%model_names[i])
        cv_score = cross_validation.cv_scheme(models[i], X_trains, y_trains)
        print('Mean cross validations score: %f\n'%cv_score)

# %%
cross_validate('dataset_6', trains, y_Ca, y_P, y_Sand, y_SOC, y_pH)
# Out:
# Model: gbr
#
# Fold: 0
# MCRMSE score for label: Ca -> 0.706801
# MCRMSE score for label: P -> 1.463820
# MCRMSE score for label: Sand -> 0.678648
# MCRMSE score for label: SOC -> 0.800042
# MCRMSE score for label: pH -> 0.651900
#
# MCRMSE score: 0.860242
#
# Fold: 1
# MCRMSE score for label: Ca -> 1.060429
# MCRMSE score for label: P -> 1.300924
# MCRMSE score for label: Sand -> 0.673482
# MCRMSE score for label: SOC -> 0.518281
# MCRMSE score for label: pH -> 0.627801
#
# MCRMSE score: 0.836184
#
# Fold: 2
# MCRMSE score for label: Ca -> 0.881758
# MCRMSE score for label: P -> 0.808320
# MCRMSE score for label: Sand -> 0.567008
# MCRMSE score for label: SOC -> 0.647887
# MCRMSE score for label: pH -> 0.642886
#
# MCRMSE score: 0.709572
#
# Fold: 3
# MCRMSE score for label: Ca -> 0.586624
# MCRMSE score for label: P -> 1.481323
# MCRMSE score for label: Sand -> 0.521044
# MCRMSE score for label: SOC -> 0.634650
# MCRMSE score for label: pH -> 0.508060
#
# MCRMSE score: 0.746340
#
# Fold: 4
# MCRMSE score for label: Ca -> 0.917614
# MCRMSE score for label: P -> 1.319416
# MCRMSE score for label: Sand -> 0.531241
# MCRMSE score for label: SOC -> 0.738942
# MCRMSE score for label: pH -> 0.627001
#
# MCRMSE score: 0.826843
#
# Fold: 5
# MCRMSE score for label: Ca -> 0.691240
# MCRMSE score for label: P -> 0.373378
# MCRMSE score for label: Sand -> 0.586337
# MCRMSE score for label: SOC -> 0.554331
# MCRMSE score for label: pH -> 0.658211
#
# MCRMSE score: 0.572699
#
# Fold: 6
# MCRMSE score for label: Ca -> 0.993811
# MCRMSE score for label: P -> 0.491031
# MCRMSE score for label: Sand -> 0.671412
# MCRMSE score for label: SOC -> 0.625899
# MCRMSE score for label: pH -> 0.768555
#
# MCRMSE score: 0.710142
#
# Fold: 7
# MCRMSE score for label: Ca -> 0.955472
# MCRMSE score for label: P -> 0.588460
# MCRMSE score for label: Sand -> 0.555053
# MCRMSE score for label: SOC -> 0.842243
# MCRMSE score for label: pH -> 0.723916
#
# MCRMSE score: 0.733029
#
# Fold: 8
# MCRMSE score for label: Ca -> 0.577580
# MCRMSE score for label: P -> 0.970171
# MCRMSE score for label: Sand -> 0.547457
# MCRMSE score for label: SOC -> 0.686392
# MCRMSE score for label: pH -> 0.705133
#
# MCRMSE score: 0.697347
#
# Fold: 9
# MCRMSE score for label: Ca -> 0.758378
# MCRMSE score for label: P -> 0.544339
# MCRMSE score for label: Sand -> 0.578160
# MCRMSE score for label: SOC -> 0.787106
# MCRMSE score for label: pH -> 0.618019
#
# MCRMSE score: 0.657201
#
# Mean cross validations score: 0.734960
#
# Model: linear
#
# Fold: 0
# MCRMSE score for label: Ca -> 0.303331
# MCRMSE score for label: P -> 1.472908
# MCRMSE score for label: Sand -> 0.572372
# MCRMSE score for label: SOC -> 0.620886
# MCRMSE score for label: pH -> 0.488856
#
# MCRMSE score: 0.691671
#
# Fold: 1
# MCRMSE score for label: Ca -> 0.661219
# MCRMSE score for label: P -> 1.242062
# MCRMSE score for label: Sand -> 0.464759
# MCRMSE score for label: SOC -> 0.407287
# MCRMSE score for label: pH -> 0.501760
#
# MCRMSE score: 0.655417
#
# Fold: 2
# MCRMSE score for label: Ca -> 0.613477
# MCRMSE score for label: P -> 0.777935
# MCRMSE score for label: Sand -> 0.398789
# MCRMSE score for label: SOC -> 0.472340
# MCRMSE score for label: pH -> 0.472174
#
# MCRMSE score: 0.546943
#
# Fold: 3
# MCRMSE score for label: Ca -> 0.328320
# MCRMSE score for label: P -> 1.403127
# MCRMSE score for label: Sand -> 0.403837
# MCRMSE score for label: SOC -> 0.462734
# MCRMSE score for label: pH -> 0.464483
#
# MCRMSE score: 0.612500
#
# Fold: 4
# MCRMSE score for label: Ca -> 0.483690
# MCRMSE score for label: P -> 1.283976
# MCRMSE score for label: Sand -> 0.475243
# MCRMSE score for label: SOC -> 0.544956
# MCRMSE score for label: pH -> 0.654123
#
# MCRMSE score: 0.688398
#
# Fold: 5
# MCRMSE score for label: Ca -> 0.402039
# MCRMSE score for label: P -> 0.387447
# MCRMSE score for label: Sand -> 0.386314
# MCRMSE score for label: SOC -> 0.362737
# MCRMSE score for label: pH -> 0.496199
#
# MCRMSE score: 0.406947
#
# Fold: 6
# MCRMSE score for label: Ca -> 0.918168
# MCRMSE score for label: P -> 0.634483
# MCRMSE score for label: Sand -> 0.591432
# MCRMSE score for label: SOC -> 0.572803
# MCRMSE score for label: pH -> 0.653477
#
# MCRMSE score: 0.674073
#
# Fold: 7
# MCRMSE score for label: Ca -> 0.505255
# MCRMSE score for label: P -> 0.580271
# MCRMSE score for label: Sand -> 0.392467
# MCRMSE score for label: SOC -> 0.751474
# MCRMSE score for label: pH -> 0.514158
#
# MCRMSE score: 0.548725
#
# Fold: 8
# MCRMSE score for label: Ca -> 0.413148
# MCRMSE score for label: P -> 1.137685
# MCRMSE score for label: Sand -> 0.426083
# MCRMSE score for label: SOC -> 0.410698
# MCRMSE score for label: pH -> 0.712695
#
# MCRMSE score: 0.620062
#
# Fold: 9
# MCRMSE score for label: Ca -> 0.489508
# MCRMSE score for label: P -> 0.442296
# MCRMSE score for label: Sand -> 0.468582
# MCRMSE score for label: SOC -> 0.826977
# MCRMSE score for label: pH -> 0.550114
#
# MCRMSE score: 0.555495
#
# Mean cross validations score: 0.600023
#
# Model: ridge
#
# Fold: 0
# MCRMSE score for label: Ca -> 0.434248
# MCRMSE score for label: P -> 1.444870
# MCRMSE score for label: Sand -> 0.566644
# MCRMSE score for label: SOC -> 0.544188
# MCRMSE score for label: pH -> 0.545527
#
# MCRMSE score: 0.707095
#
# Fold: 1
# MCRMSE score for label: Ca -> 0.616606
# MCRMSE score for label: P -> 1.277661
# MCRMSE score for label: Sand -> 0.545687
# MCRMSE score for label: SOC -> 0.445868
# MCRMSE score for label: pH -> 0.531073
#
# MCRMSE score: 0.683379
#
# Fold: 2
# MCRMSE score for label: Ca -> 0.651114
# MCRMSE score for label: P -> 0.760514
# MCRMSE score for label: Sand -> 0.437946
# MCRMSE score for label: SOC -> 0.404528
# MCRMSE score for label: pH -> 0.496693
#
# MCRMSE score: 0.550159
#
# Fold: 3
# MCRMSE score for label: Ca -> 0.385061
# MCRMSE score for label: P -> 1.524851
# MCRMSE score for label: Sand -> 0.432143
# MCRMSE score for label: SOC -> 0.463619
# MCRMSE score for label: pH -> 0.439068
#
# MCRMSE score: 0.648948
#
# Fold: 4
# MCRMSE score for label: Ca -> 0.520200
# MCRMSE score for label: P -> 1.548736
# MCRMSE score for label: Sand -> 0.502612
# MCRMSE score for label: SOC -> 0.583464
# MCRMSE score for label: pH -> 0.568666
#
# MCRMSE score: 0.744736
#
# Fold: 5
# MCRMSE score for label: Ca -> 0.345459
# MCRMSE score for label: P -> 0.432147
# MCRMSE score for label: Sand -> 0.422079
# MCRMSE score for label: SOC -> 0.391321
# MCRMSE score for label: pH -> 0.515674
#
# MCRMSE score: 0.421336
#
# Fold: 6
# MCRMSE score for label: Ca -> 0.806409
# MCRMSE score for label: P -> 0.804063
# MCRMSE score for label: Sand -> 0.597345
# MCRMSE score for label: SOC -> 0.646347
# MCRMSE score for label: pH -> 0.689708
#
# MCRMSE score: 0.708775
#
# Fold: 7
# MCRMSE score for label: Ca -> 0.587597
# MCRMSE score for label: P -> 0.773751
# MCRMSE score for label: Sand -> 0.433522
# MCRMSE score for label: SOC -> 0.685858
# MCRMSE score for label: pH -> 0.506562
#
# MCRMSE score: 0.597458
#
# Fold: 8
# MCRMSE score for label: Ca -> 0.407123
# MCRMSE score for label: P -> 1.255245
# MCRMSE score for label: Sand -> 0.437097
# MCRMSE score for label: SOC -> 0.457203
# MCRMSE score for label: pH -> 0.712807
#
# MCRMSE score: 0.653895
#
# Fold: 9
# MCRMSE score for label: Ca -> 0.422285
# MCRMSE score for label: P -> 0.469130
# MCRMSE score for label: Sand -> 0.511638
# MCRMSE score for label: SOC -> 0.798028
# MCRMSE score for label: pH -> 0.592786
#
# MCRMSE score: 0.558774
#
# Mean cross validations score: 0.627455

# %%
trains[0].columns
# Out:
# Index(['2000_0', '2000_1', '4000_0', '4000_1', '3000_0', '3000_1', '1000_0',
#        '1000_1', '<1000_0', '<1000_1'],
#       dtype='object')
